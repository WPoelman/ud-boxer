# %%
import pandas as pd
from ud_boxer.helpers import PMB
from ud_boxer.sbn_spec import get_doc_id
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")
sns.despine()

DPI = 200

lang_mapping = {
    "en": "English",
    "de": "German",
    "nl": "Dutch",
    "it": "Italian",
}

placement = {
    0: (0),
    1: (1),
    2: (2),
    3: (3),
}

palette = {
    "U - Stanza": "#50b131",
    "U - Trankit": "#f77189",
    "N - Gold": "#bb9832",
    "N - Gold & Silver": "#464d49",
    "N - Gold (strict)": "#3ba3ec",
    "N - Gold & Silver (strict)": "#e866f4",
}

# fig, axes = plt.subplots(4, 1, figsize=(8, 12), dpi=700)

# for i, lang in enumerate(["de", "nl", "it", "en"]):
for i, lang in enumerate(["it"]):
    df = pd.DataFrame()
    for data_split in ["dev", "test", "eval"]:
        if lang != "en" and data_split == "eval":
            continue

        s_df = pd.read_csv(
            f"data/results/rewrite/{lang}/{data_split}/final_stanza.csv"
        )
        t_df = pd.read_csv(
            f"data/results/rewrite/{lang}/{data_split}/final_trankit.csv"
        )
        s_df["ud_system"] = "U - Stanza"
        t_df["ud_system"] = "U - Trankit"

        df = pd.concat([df, s_df, t_df], ignore_index=True)

        if lang == "en":
            g_df = pd.read_csv(
                f"data/results/seq2seq/{data_split}/results_{data_split}_gold_only.csv"
            )
            gs_df = pd.read_csv(
                f"data/results/seq2seq/{data_split}/results_{data_split}_gold_and_silver.csv"
            )
            g_df["ud_system"] = "N - Gold"
            gs_df["ud_system"] = "N - Gold & Silver"

            df = pd.concat([df, g_df, gs_df], ignore_index=True)

            g_df = pd.read_csv(
                f"data/results/seq2seq/{data_split}/results_strict_indices_gold.csv"
            )
            gs_df = pd.read_csv(
                f"data/results/seq2seq/{data_split}/results_strict_indices_gold_silver.csv"
            )
            g_df["ud_system"] = "N - Gold (strict)"
            gs_df["ud_system"] = "N - Gold & Silver (strict)"

            df = pd.concat([df, g_df, gs_df], ignore_index=True)

        pmb = PMB(data_split, lang)
        for path in pmb.generator(
            f"../../data/pmb_dataset/pmb-extracted/pmb-4.0.0/data/{lang}/gold",
            "**/*.drs.sbn",
        ):
            doc_id = get_doc_id(lang, path)
            df.loc[df["pmb_id"] == doc_id, "gold_sbn_str"] = path.read_text().rstrip()

    df["f1"] = df["f1"].fillna(0)
    df["precision"] = df["precision"].fillna(0)
    df["recall"] = df["recall"].fillna(0)

    # ax = sns.lineplot(
    #     x="n_tokens",
    #     y="value",
    #     hue="ud_system",
    #     ci=None,
    #     data=pd.melt(
    #         df[["f1", "n_tokens", "ud_system"]],
    #         ["n_tokens", "ud_system"],
    #         var_name="Scores",
    #     ),
    #     palette=palette,
    #     linewidth=2.0,
    #     ax=axes[placement[i]],
    #     legend=i==3,
    # )
    # ax.set(ylim=(0, 1.0), xlim=(0, 35), xlabel="", ylabel="")
    # if i != 3:
    #     ax.tick_params(bottom=False)
    #     ax.set(xticklabels=[])

    # if i == 3:
    #     ax.set(xlabel="Number of tokens")

    # ax.legend(loc="lower left", facecolor="white", fontsize="10")
    # ax.set(ylabel=lang_mapping[lang])
    # ax.set_ylabel(ax.get_ylabel(), rotation=0, horizontalalignment="right")

# fig.supylabel(" ")
# # fig.suptitle(f'Scores by input length for {lang_mapping[lang]}')
# fig.suptitle(f"")
# fig.tight_layout()

# fig.savefig(f"analysis/scores_vs_len.pdf")
# Out:
# 1686it [00:00, 7261.97it/s]
# 1686it [00:00, 5892.27it/s]

# %%
df.to_csv('all_italian.csv', index=False)

# %%
selection = (
    (df['ud_system'].str.contains('Trankit')) & 
    (df.gold_sbn_str.str.count('NEGATION') == 1)
)
df[selection].sort_values('f1', ascending=False).sort_values(by="raw_sent", key=lambda x: x.str.len(), ascending=False)
# Out:
#             pmb_id source                                           raw_sent  \
# 792   de/p00/d1391   GREW  Wieviele Menschen in den USA haben keine Krank...
# 1906  de/p31/d3277   GREW    Tom süßt seinen Tee mit Honig statt mit Zucker.
# 853   de/p00/d1777   GREW           Seine Schwester geht nicht nach Amerika.
# 1047  de/p10/d2041   GREW            Ich habe keine giftigen Pilze gegessen!
# 1861  de/p41/d2274   GREW              Sie haben das Gesetz nicht gebrochen.
# 935   de/p40/d1552   GREW              Sie hat nicht mit der Wimper gezuckt.
# 787   de/p00/d1757   GREW               Der Wecker hat Tom nicht aufgeweckt.
# 1009  de/p10/d3307   GREW                 Es ist elf Uhr und er kommt nicht.
# 921   de/p40/d0769   GREW                 Ich bin überhaupt nicht überzeugt.
# 2081  de/p01/d1404   GREW                  Ich weiß nicht, wo Toms Büro ist.
# 1113  de/p20/d0867   GREW                  Der Fernseher funktioniert nicht.
# 995   de/p10/d1403   GREW                  Tom will nicht mit Mary sprechen.
# 777   de/p00/d2378   GREW                    Sie hat das Buch nicht gelesen.
# 822   de/p00/d3418   GREW                     Ich habe niemanden umgebracht!
# 817   de/p00/d1693   GREW                     Deine Witze sind nicht lustig.
# 1877  de/p91/d2487   GREW                      Die Ampel funktioniert nicht.
# 2157  de/p21/d0875   GREW                      In diesem Haus wohnt niemand.
# 947   de/p40/d0816   GREW                      Am Sonntag arbeite ich nicht.
# 2166  de/p21/d1918   GREW                       Die Waffe ist nicht geladen.
# 2155  de/p21/d0922   GREW                       Ich habe deine Nummer nicht.
# 856   de/p00/d2556   GREW                        Ich kann jetzt nicht reden.
# 1995  de/p81/d1878   GREW                        Ich traue Politikern nicht.
# 1862  de/p91/d1766   GREW                        Wir sind nicht verheiratet.
# 2088  de/p01/d1817   GREW                         Sie ist keine gute Köchin.
# 1951  de/p71/d2621   GREW                         Jim mag keine Äpfel, oder?
# 658   de/p30/d2583   GREW                         Ich habe nichts angefasst.
# 1054  de/p10/d1997   GREW                         Ich habe dich nie gesehen.
# 1793  de/p11/d2402   GREW                          Maria hat nichts gesehen.
# 993   de/p10/d1950   GREW                          Ich spreche kein Deutsch.
# 2084  de/p01/d3260   GREW                          Er ist kein guter Fahrer.
# 1043  de/p10/d2917   GREW                            Niemand ist vollkommen.
# 1002  de/p10/d0825   GREW                             Ich habe kein Fahrrad.
# 1989  de/p81/d2814   GREW                             Ich habe keinen Durst.
# 869   de/p00/d1830   GREW                             Ich bin nicht kreativ.
# 888   de/p00/d1514   GREW                              Tom kennt mich nicht.
# 1761  de/p51/d2339   GREW                                 Ist sie nicht süß?
# 1702  de/p61/d2827   GREW                                 Nichts ist heilig.
# 829   de/p00/d1994   GREW                                  Ken rannte nicht.
# 868   de/p00/d2720   GREW                                      Ich lüge nie.
#
#                                                 sbn_str  error  precision  \
# 792   time.n.08                EQU now\nwieviel.n.01...    NaN   0.531915
# 1906  time.n.08   EQU now\nfemale.n.02 Name Tom\nsüß...    NaN   0.804878
# 853   NEGATION       -1\ntime.n.08      EQU now\nSch...    NaN   0.838710
# 1047  time.n.08   EQU now\nperson.n.01 EQU speaker\n...    NaN   0.658537
# 1861  NEGATION     -1\ntime.n.08    EQU now\nperson....    NaN   0.862069
# 935   NEGATION    -1\ntime.n.08   EQU now\nfemale.n....    NaN   0.793103
# 787   NEGATION       -1\ntime.n.08      EQU now\nWec...    NaN   0.774194
# 1009  NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.513514
# 921   NEGATION       -1\ntime.n.08      EQU now\nper...    NaN   0.733333
# 2081  NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.686275
# 1113  NEGATION           -1\ntime.n.08          EQU ...    NaN   0.782609
# 995   NEGATION      -1\ntime.n.08     EQU now\nfemal...    NaN   0.818182
# 777   NEGATION    -1\ntime.n.08   EQU now\nfemale.n....    NaN   0.862069
# 822   time.n.08      EQU now\nperson.n.01    EQU spe...    NaN   0.793103
# 817   NEGATION    -1\ntime.n.08   EQU now\nWitze.n.0...    NaN   0.869565
# 1877  NEGATION           -1\ntime.n.08          EQU ...    NaN   0.826087
# 2157  NEGATION    -1\ntime.n.08   EQU now\ndies.n.01...    NaN   0.862069
# 947   NEGATION      -1\ntime.n.08     EQU now\nfemal...    NaN   0.696970
# 2166  NEGATION   -1\ntime.n.08  EQU now\nWaffe.n.01\...    NaN   0.826087
# 2155  NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.702703
# 856   NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.677419
# 1995  NEGATION       -1\ntime.n.08      EQU now\nper...    NaN   0.838710
# 1862  NEGATION         -1\ntime.n.08        EQU now\...    NaN   0.880000
# 2088  time.n.08   EQU now\nfemale.n.02\nkein.n.01\ng...    NaN   0.727273
# 1951  time.n.08  EQU now\nJim.n.01\nmögen.v.01 Time ...    NaN   0.545455
# 658   time.n.08     EQU now\nperson.n.01   EQU speak...    NaN   0.793103
# 1054  NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.848485
# 1793  time.n.08   EQU now\nfemale.n.02 Name Maria\nn...    NaN   0.724138
# 993   time.n.08     EQU now\nperson.n.01   EQU speak...    NaN   0.657143
# 2084  time.n.08   EQU now\nmale.n.02\nkein.n.01\ngut...    NaN   0.727273
# 1043  NEGATION        -1\ntime.n.08       EQU now\nv...    NaN   0.941176
# 1002  time.n.08    EQU now\nperson.n.01  EQU speaker...    NaN   0.657143
# 1989  time.n.08   EQU now\nperson.n.01 EQU speaker\n...    NaN   0.485714
# 869   NEGATION     -1\ntime.n.08    EQU now\nperson....    NaN   0.920000
# 888   NEGATION    -1\ntime.n.08   EQU now\nfemale.n....    NaN   0.818182
# 1761  NEGATION    -1\ntime.n.08   EQU now\nfemale.n....    NaN   0.913043
# 1702  time.n.08   EQU now\nnichts.n.01\nheilig.a.01 ...    NaN   0.857143
# 829   NEGATION    -1\ntime.n.08   TPR now\nfemale.n....    NaN   0.840000
# 868   NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.880000
#
#         recall        f1  precision_lenient  recall_lenient  f1_lenient  \
# 792   0.641026  0.581395           0.525000        0.617647    0.567568
# 1906  0.660000  0.725275           0.771429        0.627907    0.692308
# 853   0.604651  0.702703           0.814815        0.594595    0.687500
# 1047  0.729730  0.692308           0.657143        0.718750    0.686567
# 1861  0.641026  0.735294           0.880000        0.647059    0.745763
# 935   0.793103  0.793103           0.800000        0.800000    0.800000
# 787   0.615385  0.685714           0.814815        0.647059    0.721311
# 1009  0.542857  0.527778           0.531250        0.548387    0.539683
# 921   0.880000  0.800000           0.730769        0.863636    0.791667
# 2081  0.555556  0.614035           0.659091        0.527273    0.585859
# 1113  0.782609  0.782609           0.850000        0.850000    0.850000
# 995   0.818182  0.818182           0.827586        0.827586    0.827586
# 777   0.675676  0.757576           0.840000        0.656250    0.736842
# 822   0.741935  0.766667           0.760000        0.703704    0.730769
# 817   0.800000  0.833333           0.850000        0.772727    0.809524
# 1877  0.826087  0.826087           0.850000        0.850000    0.850000
# 2157  0.862069  0.862069           0.840000        0.840000    0.840000
# 947   0.851852  0.766667           0.689655        0.833333    0.754717
# 2166  0.826087  0.826087           0.850000        0.850000    0.850000
# 2155  0.787879  0.742857           0.718750        0.793103    0.754098
# 856   0.777778  0.724138           0.703704        0.791667    0.745098
# 1995  0.702703  0.764706           0.814815        0.687500    0.745763
# 1862  0.880000  0.880000           0.863636        0.863636    0.863636
# 2088  0.585366  0.648649           0.714286        0.571429    0.634921
# 1951  0.580645  0.562500           0.571429        0.592593    0.581818
# 658   0.741935  0.766667           0.760000        0.703704    0.730769
# 1054  0.848485  0.848485           0.827586        0.827586    0.827586
# 1793  0.677419  0.700000           0.720000        0.666667    0.692308
# 993   0.741935  0.696970           0.700000        0.777778    0.736842
# 2084  0.585366  0.648649           0.714286        0.571429    0.634921
# 1043  0.695652  0.800000           0.933333        0.700000    0.800000
# 1002  0.741935  0.696970           0.666667        0.740741    0.701754
# 1989  0.680000  0.566667           0.500000        0.681818    0.576923
# 869   0.920000  0.920000           0.909091        0.909091    0.909091
# 888   0.818182  0.818182           0.827586        0.827586    0.827586
# 1761  0.913043  0.913043           0.900000        0.900000    0.900000
# 1702  0.782609  0.818182           0.833333        0.750000    0.789474
# 829   0.840000  0.840000           0.818182        0.818182    0.818182
# 868   0.880000  0.880000           0.909091        0.909091    0.909091
#
#         ud_system                                       gold_sbn_str
# 792   U - Trankit  %%% This output was generated by the following...
# 1906  U - Trankit  %%% This output was generated by the following...
# 853   U - Trankit  %%% This output was generated by the following...
# 1047  U - Trankit  %%% This output was generated by the following...
# 1861  U - Trankit  %%% This output was generated by the following...
# 935   U - Trankit  %%% This output was generated by the following...
# 787   U - Trankit  %%% This output was generated by the following...
# 1009  U - Trankit  %%% This output was generated by the following...
# 921   U - Trankit  %%% This output was generated by the following...
# 2081  U - Trankit  %%% This output was generated by the following...
# 1113  U - Trankit  %%% This output was generated by the following...
# 995   U - Trankit  %%% This output was generated by the following...
# 777   U - Trankit  %%% This output was generated by the following...
# 822   U - Trankit  %%% This output was generated by the following...
# 817   U - Trankit  %%% This output was generated by the following...
# 1877  U - Trankit  %%% This output was generated by the following...
# 2157  U - Trankit  %%% This output was generated by the following...
# 947   U - Trankit  %%% This output was generated by the following...
# 2166  U - Trankit  %%% This output was generated by the following...
# 2155  U - Trankit  %%% This output was generated by the following...
# 856   U - Trankit  %%% This output was generated by the following...
# 1995  U - Trankit  %%% This output was generated by the following...
# 1862  U - Trankit  %%% This output was generated by the following...
# 2088  U - Trankit  %%% This output was generated by the following...
# 1951  U - Trankit  %%% This output was generated by the following...
# 658   U - Trankit  %%% This output was generated by the following...
# 1054  U - Trankit  %%% This output was generated by the following...
# 1793  U - Trankit  %%% This output was generated by the following...
# 993   U - Trankit  %%% This output was generated by the following...
# 2084  U - Trankit  %%% This output was generated by the following...
# 1043  U - Trankit  %%% This output was generated by the following...
# 1002  U - Trankit  %%% This output was generated by the following...
# 1989  U - Trankit  %%% This output was generated by the following...
# 869   U - Trankit  %%% This output was generated by the following...
# 888   U - Trankit  %%% This output was generated by the following...
# 1761  U - Trankit  %%% This output was generated by the following...
# 1702  U - Trankit  %%% This output was generated by the following...
# 829   U - Trankit  %%% This output was generated by the following...
# 868   U - Trankit  %%% This output was generated by the following...

# %%
# Loop over data split in pmb and add original sbn string to csv
# negation precision recall f1 sbn_str vs gold_sbn_str

# Best scoring sentences
df[selection].sort_values('f1', ascending=False).head(10).sort_values(by="raw_sent", key=lambda x: x.str.len(), ascending=False)
# Out:
#             pmb_id source                        raw_sent  \
# 817   de/p00/d1693   GREW  Deine Witze sind nicht lustig.
# 2157  de/p21/d0875   GREW   In diesem Haus wohnt niemand.
# 1877  de/p91/d2487   GREW   Die Ampel funktioniert nicht.
# 2166  de/p21/d1918   GREW    Die Waffe ist nicht geladen.
# 1862  de/p91/d1766   GREW     Wir sind nicht verheiratet.
# 1054  de/p10/d1997   GREW      Ich habe dich nie gesehen.
# 869   de/p00/d1830   GREW          Ich bin nicht kreativ.
# 1761  de/p51/d2339   GREW              Ist sie nicht süß?
# 829   de/p00/d1994   GREW               Ken rannte nicht.
# 868   de/p00/d2720   GREW                   Ich lüge nie.
#
#                                                 sbn_str  error  precision  \
# 817   NEGATION    -1\ntime.n.08   EQU now\nWitze.n.0...    NaN   0.869565
# 2157  NEGATION    -1\ntime.n.08   EQU now\ndies.n.01...    NaN   0.862069
# 1877  NEGATION           -1\ntime.n.08          EQU ...    NaN   0.826087
# 2166  NEGATION   -1\ntime.n.08  EQU now\nWaffe.n.01\...    NaN   0.826087
# 1862  NEGATION         -1\ntime.n.08        EQU now\...    NaN   0.880000
# 1054  NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.848485
# 869   NEGATION     -1\ntime.n.08    EQU now\nperson....    NaN   0.920000
# 1761  NEGATION    -1\ntime.n.08   EQU now\nfemale.n....    NaN   0.913043
# 829   NEGATION    -1\ntime.n.08   TPR now\nfemale.n....    NaN   0.840000
# 868   NEGATION    -1\ntime.n.08   EQU now\nperson.n....    NaN   0.880000
#
#         recall        f1  precision_lenient  recall_lenient  f1_lenient  \
# 817   0.800000  0.833333           0.850000        0.772727    0.809524
# 2157  0.862069  0.862069           0.840000        0.840000    0.840000
# 1877  0.826087  0.826087           0.850000        0.850000    0.850000
# 2166  0.826087  0.826087           0.850000        0.850000    0.850000
# 1862  0.880000  0.880000           0.863636        0.863636    0.863636
# 1054  0.848485  0.848485           0.827586        0.827586    0.827586
# 869   0.920000  0.920000           0.909091        0.909091    0.909091
# 1761  0.913043  0.913043           0.900000        0.900000    0.900000
# 829   0.840000  0.840000           0.818182        0.818182    0.818182
# 868   0.880000  0.880000           0.909091        0.909091    0.909091
#
#         ud_system                                       gold_sbn_str
# 817   U - Trankit  %%% This output was generated by the following...
# 2157  U - Trankit  %%% This output was generated by the following...
# 1877  U - Trankit  %%% This output was generated by the following...
# 2166  U - Trankit  %%% This output was generated by the following...
# 1862  U - Trankit  %%% This output was generated by the following...
# 1054  U - Trankit  %%% This output was generated by the following...
# 869   U - Trankit  %%% This output was generated by the following...
# 1761  U - Trankit  %%% This output was generated by the following...
# 829   U - Trankit  %%% This output was generated by the following...
# 868   U - Trankit  %%% This output was generated by the following...

# %%
file = 'all_german.csv'
df = pd.read_csv(file)

full = ''
for system in ['Stanza', 'Trankit']:
    for i in range(1, 5):
        selection = (
            # (df['ud_system'] == 'N - Gold (strict)') & 
            (df['ud_system'].str.contains(system)) & 
            (df.sbn_str.str.count('NEGATION') == i)
        )
        msg = f"""
        SYSTEM: {system}
        COUNT:  {i}
        LANG:   {file}

        AVERAGE P (strict):  {100 * df[selection]["precision"].mean():.3}
        AVERAGE R (strict): {100 * df[selection]["recall"].mean():.3}
        AVERAGE F1 (strict): {100 * df[selection]["f1"].mean():.3}

        """
        full += f' & {100 * df[selection]["precision"].mean():.3} & {100 * df[selection]["recall"].mean():.3} & {100 * df[selection]["f1"].mean():.3}'
        print(msg)
    print(full)
# Out:
#         SYSTEM: Stanza
#         COUNT:  1
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  80.4
#         AVERAGE R (strict): 77.3
#         AVERAGE F1 (strict): 78.2
#
#
#
#         SYSTEM: Stanza
#         COUNT:  2
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  84.4
#         AVERAGE R (strict): 72.3
#         AVERAGE F1 (strict): 77.4
#
#
#
#         SYSTEM: Stanza
#         COUNT:  3
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  nan
#         AVERAGE R (strict): nan
#         AVERAGE F1 (strict): nan
#
#
#
#         SYSTEM: Stanza
#         COUNT:  4
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  nan
#         AVERAGE R (strict): nan
#         AVERAGE F1 (strict): nan
#
#
#  & 80.4 & 77.3 & 78.2 & 84.4 & 72.3 & 77.4 & nan & nan & nan & nan & nan & nan
#
#         SYSTEM: Trankit
#         COUNT:  1
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  79.9
#         AVERAGE R (strict): 78.0
#         AVERAGE F1 (strict): 78.4
#
#
#
#         SYSTEM: Trankit
#         COUNT:  2
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  83.7
#         AVERAGE R (strict): 72.9
#         AVERAGE F1 (strict): 77.6
#
#
#
#         SYSTEM: Trankit
#         COUNT:  3
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  nan
#         AVERAGE R (strict): nan
#         AVERAGE F1 (strict): nan
#
#
#
#         SYSTEM: Trankit
#         COUNT:  4
#         LANG:   all_german.csv
#
#         AVERAGE P (strict):  nan
#         AVERAGE R (strict): nan
#         AVERAGE F1 (strict): nan
#
#
#  & 80.4 & 77.3 & 78.2 & 84.4 & 72.3 & 77.4 & nan & nan & nan & nan & nan & nan & 79.9 & 78.0 & 78.4 & 83.7 & 72.9 & 77.6 & nan & nan & nan & nan & nan & nan

# %%
df = pd.read_csv('all_dutch.csv')

full_cnt = ""
df_tmp = df.drop_duplicates(['pmb_id'])
for i in range(0, 10):
    cnt = len(df_tmp[df_tmp.gold_sbn_str.str.count('NEGATION') == i])
    print(f'{i} -> {cnt}')
    full_cnt += f'& {cnt}'
print(full_cnt)
# Out:
# 0 -> 841
# 1 -> 65
# 2 -> 20
# 3 -> 2
# 4 -> 0
# 5 -> 0
# 6 -> 0
# 7 -> 0
# 8 -> 0
# 9 -> 0
# & 841& 65& 20& 2& 0& 0& 0& 0& 0& 0

# %%
print('\n\n'.join(df[df.gold_sbn_str.str.count('NEGATION') == 4].gold_sbn_str.tolist()))
# Out:
# %%% This output was generated by the following command:
# %%% bin/boxer --input out/p01/d2144/de.parse.tags --semantics sbn --resolve --tense --instantiate --modal --theory sdrt --copula false --nn --elimeq --roles verbnet --integrate --warnings false --output out/p01/d2144/de.drs.sbn
#             NEGATION -1                        % Jeder  [0-5]
# person.n.01                                    %
#             NEGATION -1                        %
#             NEGATION -1                        % jeden. [12-18]
# person.n.01                                    %
#             NEGATION -1                        %
# know.v.04   Experiencer -2 Stimulus -1 Time +1 % kennt  [6-11]
# time.n.08   EQU now                            %
#
# %%% This output was generated by the following command:
# %%% bin/boxer --input out/p01/d2144/de.parse.tags --semantics sbn --resolve --tense --instantiate --modal --theory sdrt --copula false --nn --elimeq --roles verbnet --integrate --warnings false --output out/p01/d2144/de.drs.sbn
#             NEGATION -1                        % Jeder  [0-5]
# person.n.01                                    %
#             NEGATION -1                        %
#             NEGATION -1                        % jeden. [12-18]
# person.n.01                                    %
#             NEGATION -1                        %
# know.v.04   Experiencer -2 Stimulus -1 Time +1 % kennt  [6-11]
# time.n.08   EQU now                            %

# %%
from sklearn.metrics import classification_report

# for file in ['all_english.csv', 'all_dutch.csv', 'all_italian.csv', 'all_german.csv']:
for file in ['all_english.csv']:
    df = pd.read_csv(file)
    # for system in ['Stanza', 'Trankit']:
    for system in ['N - Gold (strict)', 'N - Gold & Silver (strict)']:
        selection = (
            # df['ud_system'].str.contains(system)
            df['ud_system'] == system
        )
        y_true = df[selection].gold_sbn_str.str.count('NEGATION')
        y_pred = df[selection].sbn_str.str.count('NEGATION').fillna(-1)
        print(f'{file} -> {system}')
        print(classification_report(y_true, y_pred, digits=3))
        print(f'\n\n')
# Out:
# all_english.csv -> N - Gold (strict)
#               precision    recall  f1-score   support
#
#         -1.0      0.000     0.000     0.000         0
#          0.0      0.983     0.910     0.945      2676
#          1.0      0.765     0.810     0.787       253
#          2.0      0.780     0.419     0.545        93
#          3.0      0.000     0.000     0.000         7
#          4.0      0.500     0.400     0.444         5
#
#     accuracy                          0.883      3034
#    macro avg      0.505     0.423     0.454      3034
# weighted avg      0.956     0.883     0.916      3034
#
#
#
#
# all_english.csv -> N - Gold & Silver (strict)
#               precision    recall  f1-score   support
#
#         -1.0      0.000     0.000     0.000         0
#          0.0      0.995     0.965     0.980      2676
#          1.0      0.964     0.953     0.958       253
#          2.0      0.941     0.860     0.899        93
#          3.0      0.600     0.429     0.500         7
#          4.0      1.000     0.200     0.333         5
#          6.0      0.000     0.000     0.000         0
#
#     accuracy                          0.958      3034
#    macro avg      0.643     0.487     0.524      3034
# weighted avg      0.990     0.958     0.973      3034
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/wessel/miniconda3/envs/thesis/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df[df['pmb_id'] == 'en/p01/d2144']
# Out:
#              pmb_id   source                  raw_sent  \
# 7667   en/p01/d2144     GREW  Everyone knows everyone.
# 8714   en/p01/d2144     GREW  Everyone knows everyone.
# 9757   en/p01/d2144  SEQ2SEQ  Everyone knows everyone.
# 10802  en/p01/d2144  SEQ2SEQ  Everyone knows everyone.
# 11841  en/p01/d2144  SEQ2SEQ  Everyone knows everyone.
# 12889  en/p01/d2144  SEQ2SEQ  Everyone knows everyone.
#
#                                                  sbn_str error  precision  \
# 7667   NEGATION      -1\nNEGATION      -1\ntime.n.08 ...   NaN   0.800000
# 8714   NEGATION      -1\nNEGATION      -1\ntime.n.08 ...   NaN   0.800000
# 9757   NEGATION    -1\nperson.n.01\nNEGATION    -1\nN...   NaN   0.971429
# 10802  NEGATION    -1\nperson.n.01\nNEGATION    -1\nN...   NaN   0.772727
# 11841  NEGATION    -1\nperson.n.01\nNEGATION    -1\nN...   NaN   0.971429
# 12889  NEGATION    -1\nperson.n.01\nNEGATION    -1\nN...   NaN   0.772727
#
#          recall        f1  precision_lenient  recall_lenient  f1_lenient  \
# 7667   0.571429  0.666667           0.818182        0.580645    0.679245
# 8714   0.571429  0.666667           0.818182        0.580645    0.679245
# 9757   0.971429  0.971429           0.967742        0.967742    0.967742
# 10802  0.971429  0.860759           0.769231        0.967742    0.857143
# 11841  0.971429  0.971429                NaN             NaN         NaN
# 12889  0.971429  0.860759                NaN             NaN         NaN
#
#                         ud_system  \
# 7667                   U - Stanza
# 8714                  U - Trankit
# 9757                     N - Gold
# 10802           N - Gold & Silver
# 11841           N - Gold (strict)
# 12889  N - Gold & Silver (strict)
#
#                                             gold_sbn_str
# 7667   %%% This output was generated by the following...
# 8714   %%% This output was generated by the following...
# 9757   %%% This output was generated by the following...
# 10802  %%% This output was generated by the following...
# 11841  %%% This output was generated by the following...
# 12889  %%% This output was generated by the following...

# %%
print('\n\n'.join(df[df.sbn_str.str.count('NEGATION') == 6].sbn_str.tolist()))
# Out:
# NEGATION    -1
# person.n.01
# NEGATION    -1
# NEGATION    -1
# person.n.01
# NEGATION    -1
# NEGATION    -1
# person.n.01
# NEGATION    -1
# know.v.04   Experiencer -2 Stimulus -1 Time +1
# time.n.08   EQU now
#
# NEGATION    -1
# person.n.01
# NEGATION    -1
# NEGATION    -1
# person.n.01
# NEGATION    -1
# NEGATION    -1
# person.n.01
# NEGATION    -1
# know.v.04   Experiencer -2 Stimulus -1 Time +1
# time.n.08   EQU now
