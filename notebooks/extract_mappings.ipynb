# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv('data/edge_classifier/nl_edge_mappings_2022_05_24_20_22_21.csv')

# %%
df.head()
# Out:
#   from_node_token from_node_Gender from_node_Number from_node_lemma  \
# 0     female.n.02              Com             Sing            Mary
# 1     molken.v.01              NaN              NaN          molken
# 2     molken.v.01              NaN              NaN          molken
# 3       time.n.08              NaN              NaN             NaN
# 4   gelukkig.a.01              NaN              NaN        gelukkig
#
#   from_node_upos              from_node_xpos to_node_token deprel  label  \
# 0          PROPN  N|eigen|ev|basis|zijd|stan          Mary    NaN   Name
# 1           VERB           WW|vd|vrij|zonder   female.n.02  nsubj  Agent
# 2           VERB           WW|vd|vrij|zonder     time.n.08    NaN   Time
# 3            NaN                         NaN           now    NaN    EQU
# 4            ADJ       ADJ|vrij|basis|zonder     time.n.08    NaN   Time
#
#          doc_id  ... to_node_Person to_node_PronType from_node_Case  \
# 0  nl/p96/d2299  ...            NaN              NaN            NaN
# 1  nl/p96/d2299  ...            NaN              NaN            NaN
# 2  nl/p96/d2299  ...            NaN              NaN            NaN
# 3  nl/p96/d1684  ...            NaN              NaN            NaN
# 4  nl/p96/d1684  ...            NaN              NaN            NaN
#
#   from_node_Person from_node_PronType to_node_Degree to_node_Poss  \
# 0              NaN                NaN            NaN          NaN
# 1              NaN                NaN            NaN          NaN
# 2              NaN                NaN            NaN          NaN
# 3              NaN                NaN            NaN          NaN
# 4              NaN                NaN            NaN          NaN
#
#   to_node_Tense to_node_VerbForm  from_node_Poss
# 0           NaN              NaN             NaN
# 1           NaN              NaN             NaN
# 2           NaN              NaN             NaN
# 3           NaN              NaN             NaN
# 4           NaN              NaN             NaN
#
# [5 rows x 29 columns]

# %%
df[df.from_node_lemma.notna()]['from_node_lemma']
# Out:
# 0             Mary
# 1           molken
# 2           molken
# 4         gelukkig
# 5      terug_slaan
#           ...
# 842         gitaar
# 844             ik
# 845      begrijpen
# 847           zijn
# 848           zijn
# Name: from_node_lemma, Length: 650, dtype: object

# %%
from ud_boxer.sbn_spec import split_synset_id

lemma_to_sense = dict()
lemma_pos_to_sense = dict()

for _, row in df.iterrows():
    for n in ['from', 'to']:
        sense = row[f"{n}_node_token"]
        if not (components := split_synset_id(sense)):
            continue
        
        _, pos, num = components
        lemma = row[f'{n}_node_lemma']
        if lemma in lemma_to_sense:
            if sense in lemma_to_sense[lemma]:
                lemma_to_sense[lemma][sense] += 1
            else:
                lemma_to_sense[lemma][sense] = 1
        else:
            lemma_to_sense[lemma] = {sense: 1}

        lemma_pos = f'{lemma}.{pos}'
        if lemma_pos in lemma_pos_to_sense:
            if sense in lemma_pos_to_sense[lemma_pos]:
                lemma_pos_to_sense[lemma_pos][sense] += 1
            else:
                lemma_pos_to_sense[lemma_pos][sense] = 1
        else:
            lemma_pos_to_sense[lemma_pos] = {sense: 1}

# %%
def filter_most_common(mapping_dict):
    filtered_dict = dict()
    for lem, count_dict in mapping_dict.items():
        if len(count_dict) == 1:
            filtered_dict[lem] = list(count_dict.keys())[0]
        else:
            filtered_dict[lem] = sorted(list(count_dict.items()), key=lambda x: x[1])[-1][0]
    return filtered_dict

# %%
most_common_lemma_to_sense = filter_most_common(lemma_to_sense)
most_common_lemma_pos_to_sense = filter_most_common(lemma_pos_to_sense)

# %%
import json

with open('data/mappings/nl_lemma_sense_lookup_train.json', 'w') as f:
    json.dump(most_common_lemma_to_sense, f, indent=4)

with open('data/mappings/nl_lemma_pos_sense_lookup_train.json', 'w') as f:
    json.dump(most_common_lemma_pos_to_sense, f, indent=4)

# %%
lemma_pos_to_sense
# Out:
# {'starren.v': {'starren_an.v.01': 4},
#  'Sie|sie.n': {'female.n.02': 52, 'person.n.01': 8},
#  'nan.n': {'time.n.08': 1106},
#  'ich.n': {'person.n.01': 131},
#  'glücklich.a': {'glücklich.a.01': 6},
#  'verloben.a': {'verloben.a.01': 3},
#  'ohrfeigen.v': {'ohrfeigen.v.01': 2},
#  'bellen.v': {'bellen.v.01': 2, 'bellen_an.v.01': 1},
#  'dauern.v': {'dauern.v.01': 4},
#  'Versammlung.n': {'Versammlung.n.01': 1},
#  'unvoreingenommen.a': {'unvoreingenommen.a.01': 3},
#  'er.n': {'male.n.02': 72},
#  'äußerst.r': {'äußerst.r.01': 3},
#  'süß.a': {'süß.a.01': 2},
#  'Banan.n': {'Banan.n.01': 1},
#  'setzen.v': {'setzen.v.01': 2},
#  'Pferd.n': {'Pferd.n.01': 1},
#  'wiegen.v': {'wiegen.v.01': 2},
#  '140.n': {'140.n.01': 2},
#  'etwa.r': {'etwa.r.01': 2},
#  'Kilogramm.n': {'Kilogramm.n.01': 1},
#  'lösen.v': {'lösen.v.01': 4},
#  'Rätsel.n': {'Rätsel.n.01': 1},
#  'Tom.n': {'female.n.02': 40},
#  'bießen.v': {'bießen.v.01': 2},
#  'Mary.n': {'female.n.02': 11},
#  'wimmern.v': {'wimmern.v.01': 1},
#  'Schmerz.n': {'Schmerz.n.01': 2},
#  'Gianni.n': {'female.n.02': 2},
#  'Designer.n': {'Designer.n.01': 1},
#  'Marika.n': {'female.n.02': 1},
#  'verstehen.v': {'verstehen.v.01': 2},
#  'einfach.a': {'einfach.a.01': 2},
#  'der.n': {'der.n.01': 10},
#  'niederstechen.v': {'niederstechen.v.01': 1},
#  'Marlowe.n': {'female.n.02': 1},
#  'Brad.n': {'female.n.02': 2},
#  'Schauspieler.n': {'Schauspieler.n.01': 2},
#  'schießen.v': {'schießen.v.01': 4},
#  'Alaska.n': {'female.n.02': 2},
#  'leben.v': {'leben.v.01': 7},
#  'Million.n': {'Million.n.01': 1},
#  'Lauf.n': {'Lauf.n.01': 1},
#  'auszählen.v': {'auszählen.v.01': 1},
#  'Jim.n': {'female.n.02': 1},
#  'treffen|triefen.v': {'treffen|triefen.v.01': 2},
#  'neugierig.a': {'neugierig.a.01': 2},
#  'sehr.r': {'sehr.r.01': 11},
#  'Maria.n': {'female.n.02': 19},
#  'lang.a': {'lang.a.01': 4},
#  'Haar.n': {'Haar.n.01': 1},
#  'ernennen.v': {'ernennen.v.01': 4},
#  'Vorsitzende.n': {'Vorsitzende.n.01': 1},
#  'befestigt.v': {'befestigt.v.01': 1},
#  'Drache.n': {'Drache.n.01': 1},
#  'Ken..n': {'female.n.02': 1},
#  'adoptieren.v': {'adoptieren.v.01': 1},
#  'Kind.n': {'Kind.n.01': 3},
#  'tragen.v': {'tragen.v.01': 16},
#  'Brille.n': {'Brille.n.01': 1},
#  'gewinnen.v': {'gewinnen.v.01': 13},
#  'Goldmedaille.n': {'Goldmedaille.n.01': 4},
#  'leiden.v': {'leiden.v.01': 4},
#  'sparen.v': {'sparen.v.01': 2},
#  'verblüffen.a': {'verblüffen.a.01': 1},
#  'völlig.r': {'völlig.r.01': 1},
#  'entkommen.v': {'entkommen.v.01': 2},
#  'Gefangene.n': {'Gefangene.n.01': 1},
#  'Detektiv.n': {'Detektiv.n.01': 1},
#  'sterben.v': {'sterben.v.01': 2},
#  'WEDCOR.n': {'female.n.02': 1},
#  'arbeiten.v': {'arbeiten.v.01': 5},
#  'Beverly.n': {'female.n.02': 1},
#  'schnüffeln.v': {'schnüffeln.v.01': 2},
#  'Boden.n': {'Boden.n.01': 2},
#  'glauben.v': {'glauben.v.01': 3},
#  'Erderwärmung.n': {'Erderwärmung.n.01': 1},
#  'stinkreich.a': {'stinkreich.a.01': 2},
#  'vertiefen.a': {'vertiefen.a.01': 3},
#  'vermieten.v': {'vermieten.v.01': 1},
#  'Wohnung.n': {'Wohnung.n.01': 1},
#  'behandeln.v': {'behandeln.v.01': 1},
#  'hassen.v': {'hassen.v.01': 4},
#  'schalden.v': {'schalden.v.01': 2},
#  'du.n': {'person.n.01': 27},
#  'Biene.n': {'Biene.n.01': 3},
#  'Hornisse.n': {'Hornisse.n.01': 1},
#  'Wespen.n': {'Wespen.n.01': 2},
#  'warten.v': {'warten.v.01': 4},
#  'zehn.n': {'zehn.n.01': 3},
#  'ungefähr.r': {'ungefähr.r.01': 3},
#  'Leute.n': {'Leute.n.01': 4},
#  'stinken.v': {'stinken.v.01': 3},
#  'Socke.n': {'Socke.n.01': 1},
#  'fressen.v': {'fressen.v.01': 5},
#  '300.n': {'300.n.01': 4},
#  'Pfund.n': {'Pfund.n.01': 2},
#  'retten.v': {'retten.v.01': 2},
#  'Autofahrer.n': {'Autofahrer.n.01': 1},
#  'giftig.a': {'giftig.a.01': 2},
#  'klopfen.v': {'klopfen.v.01': 17},
#  'jemand.n': {'jemand.n.01': 12},
#  'Wasservogel.n': {'Wasservogel.n.01': 2},
#  'Gan.n': {'Gan.n.01': 1},
#  'heiraten.v': {'heiraten.v.01': 12},
#  'kopieren.v': {'kopieren.v.01': 1},
#  'Dokument.n': {'Dokument.n.01': 1},
#  'hinrichten.v': {'hinrichten.v.01': 1},
#  'winken.v': {'winken_zu.v.01': 1, 'winken.v.01': 1},
#  'krechen.v': {'krechen.v.01': 2},
#  'werfen.v': {'werfen_zu.v.01': 1, 'werfen.v.01': 5},
#  'Schlüssel.n': {'Schlüssel.n.01': 2},
#  'verrücken.a': {'verrücken.a.01': 5},
#  'total.v': {'total.v.02': 1},
#  'ertönen.v': {'ertönen.v.01': 2},
#  'Pfiff.n': {'Pfiff.n.01': 1},
#  'treten.v': {'treten.v.01': 5, 'treten_zurück.v.01': 2},
#  'Spinnenbiss.n': {'Spinnenbiss.n.01': 1},
#  'spielen.v': {'spielen.v.01': 28},
#  'Schach.n': {'Schach.n.01': 1},
#  'Jorge.n': {'female.n.02': 1},
#  'Miesepeter.n': {'Miesepeter.n.01': 1},
#  'berauben.v': {'berauben.v.01': 2},
#  'Dame.n': {'Dame.n.01': 2},
#  'alt.a': {'alt.a.01': 12},
#  'schwimmen.v': {'schwimmen.v.01': 1},
#  'mögen.v': {'mögen.v.01': 2},
#  'Korsika.n': {'female.n.02': 2},
#  'Napoleon.n': {'female.n.02': 3},
#  'gebären.v': {'gebären.v.01': 5},
#  'wir.n': {'person.n.01': 22},
#  'bombardieren.v': {'bombardieren.v.01': 1},
#  'London.n': {'female.n.02': 1},
#  'Spocks.n': {'female.n.02': 1},
#  'kommen.v': {'kommen.v.01': 4, 'kommen_zu.v.01': 2},
#  'Rockgruppe.n': {'Rockgruppe.n.01': 1},
#  'Japan.n': {'female.n.02': 3},
#  'bestechen.v': {'bestechen.v.01': 1},
#  'Madrilene.n': {'Madrilene.n.01': 1},
#  'sein.v': {'sein.v.01': 1},
#  'zerkrümeln.v': {'zerkrümeln.v.01': 2},
#  'trinkbar.a': {'trinkbar.a.01': 2},
#  'Wasser.n': {'Wasser.n.01': 3},
#  'pflanzen.v': {'pflanzen.v.01': 5},
#  'Orangenbaum.n': {'Orangenbaum.n.01': 1},
#  'Bäcker.n': {'Bäcker.n.01': 1},
#  'verletzen.v': {'verletzen.v.01': 1},
#  'haben.v': {'haben.v.01': 16},
#  'Auge.n': {'Auge.n.01': 1},
#  'Flamme.n': {'Flamme.n.01': 1},
#  'fangen.v': {'fangen.v.01': 1},
#  'Netz.n': {'Netz.n.01': 1},
#  'pflücken.v': {'pflücken.v.01': 10},
#  'Blume.n': {'Blume.n.01': 4},
#  'engagieren.v': {'engagieren.v.01': 3},
#  'Privatdetektiv.n': {'Privatdetektiv.n.01': 1},
#  'rot.a': {'rot.a.01': 4},
#  'Australien.n': {'female.n.02': 1},
#  'Gold.n': {'Gold.n.01': 1},
#  'erpressen.v': {'erpressen.v.01': 6},
#  'klingeln.v': {'klingeln.v.01': 4},
#  'Wecker.n': {'Wecker.n.01': 1},
#  'überraschen.v': {'überraschen.v.01': 2},
#  'maßgeschneidert.a': {'maßgeschneidert.a.01': 2},
#  'Anzug.n': {'Anzug.n.01': 1},
#  'zahlen.v': {'zahlen.v.01': 7},
#  'Bußgeld.n': {'Bußgeld.n.01': 1},
#  'umarmen.v': {'umarmen.v.01': 2},
#  'verseuchen.a': {'verseuchen.a.01': 2},
#  'See.n': {'See.n.01': 2},
#  'Ministerpräsident.n': {'Ministerpräsident.n.01': 1},
#  'Telefon.n': {'Telefon.n.01': 1},
#  'Greenpeace.n': {'female.n.02': 1},
#  'Verstorbene.n': {'Verstorbene.n.01': 1},
#  'widersprechen.v': {'widersprechen.v.01': 2},
#  'Darwins.n': {'female.n.02': 1},
#  'Dollar.n': {'Dollar.n.01': 6, 'female.n.02': 1},
#  'fünfzig.n': {'fünfzig.n.01': 1},
#  'gackern.v': {'gackern.v.01': 1},
#  '20.n': {'20.n.01': 1},
#  'wählen.v': {'wählen.v.01': 1},
#  'Telefonnummer.n': {'Telefonnummer.n.01': 1},
#  'Gegner.n': {'Gegner.n.01': 1},
#  'schluchzen.v': {'schluchzen.v.01': 2},
#  'beschuldigen.v': {'beschuldigen.v.01': 1},
#  'O.J..n': {'female.n.02': 1},
#  'vergessen.v': {'vergessen.v.01': 2},
#  'Ketchup.n': {'Ketchup.n.01': 1},
#  'funktionieren.v': {'funktionieren.v.01': 6},
#  'Ventilator.n': {'Ventilator.n.01': 1},
#  'zerstören.v': {'zerstören.v.01': 1},
#  'sagen.v': {'sagen.v.01': 2, 'sagen_ab.v.01': 1},
#  'Betty.n': {'female.n.02': 2},
#  'Serienmörderin.n': {'Serienmörderin.n.01': 1},
#  'stockbesoffen.a': {'stockbesoffen.a.01': 2},
#  'schön.a': {'schön.a.01': 6},
#  'Mutter.n': {'Mutter.n.01': 3},
#  'überfahren.v': {'überfahren.v.01': 2},
#  'spülen.v': {'spülen_ab.v.01': 1},
#  'Seife.n': {'Seife.n.01': 1},
#  'freundlich.a': {'freundlich.a.01': 2},
#  'Airbus.n': {'female.n.02': 1},
#  'MG.n': {'female.n.02': 1},
#  'aufkaufen.v': {'aufkaufen.v.01': 1},
#  'kitzeln.v': {'kitzeln.v.01': 1},
#  'Buch.n': {'Buch.n.01': 8},
#  'schlafen.v': {'schlafen.v.01': 6, 'schlafen_ein.v.01': 1},
#  'lieben.v': {'lieben.v.01': 4},
#  'reichen.v': {'reichen.v.01': 2},
#  'Cocktail.n': {'Cocktail.n.01': 1},
#  'hören.v': {'hören.v.01': 1},
#  'niemand.n': {'niemand.n.01': 7},
#  'GUS.n': {'female.n.02': 1},
#  'verkaufen.v': {'verkaufen.v.01': 2},
#  'Wehkamp.n': {'female.n.02': 1},
#  'Ägypten.n': {'female.n.02': 2},
#  'verwandeln.v': {'verwandeln.v.01': 1},
#  'erschüttern.v': {'erschüttern.v.01': 1},
#  'Fulham.n': {'female.n.02': 1},
#  'schnurren.v': {'schnurren.v.01': 1},
#  'trenken.v': {'trenken.v.01': 4},
#  'rasen.v': {'rasen_entlang.v.01': 2},
#  'Lastwagen.n': {'Lastwagen.n.01': 2},
#  'zweitausend.n': {'zweitausend.n.01': 2},
#  'Mann.n': {'Mann.n.01': 1},
#  'nennen.v': {'nennen.v.01': 3},
#  'Charles.n': {'female.n.02': 1},
#  'ermorden.v': {'ermorden.v.01': 5},
#  'Anna.n': {'female.n.02': 1},
#  'geben.v': {'geben_ein.v.01': 1, 'geben.v.01': 3},
#  'Paßwort.n': {'Paßwort.n.01': 1},
#  'erschielen.v': {'erschielen.v.01': 2},
#  'Feueralarm.n': {'Feueralarm.n.01': 1},
#  'leihen.v': {'leihen.v.01': 2},
#  'einstecken.v': {'einstecken.v.01': 2},
#  'Münze.n': {'Münze.n.01': 1},
#  'winnen.v': {'winnen.v.01': 2},
#  'jed.n': {'jed.n.01': 3},
#  'stolz.a': {'stolz.a.01': 1},
#  'Steffi.n': {'female.n.02': 2},
#  'schlagen.v': {'schlagen.v.01': 6},
#  'Conchita.n': {'female.n.02': 1},
#  'legal.a': {'legal.a.01': 1},
#  'Prostitution.n': {'Prostitution.n.01': 1},
#  'holen.v': {'holen.v.01': 1},
#  'USA.n': {'female.n.02': 1},
#  'Kanada.n': {'female.n.02': 1},
#  'Kairo.n': {'female.n.02': 1},
#  'wohnen.v': {'wohnen.v.01': 1},
#  'Missouri.n': {'female.n.02': 1},
#  'grenzen.v': {'grenzen.v.01': 4},
#  'Illinois.n': {'female.n.02': 1},
#  'blöken.v': {'blöken.v.01': 1},
#  'verschlingen.v': {'verschlingen.v.01': 1},
#  'Ausweis.n': {'Ausweis.n.01': 2},
#  'gefälscht.a': {'gefälscht.a.01': 1},
#  'benutzen.v': {'benutzen.v.01': 7},
#  'segnen.v': {'segnen.v.01': 2},
#  'Priester.n': {'Priester.n.01': 1},
#  'offensichtlich.a': {'offensichtlich.a.01': 2},
#  'Antwort.n': {'Antwort.n.01': 1},
#  'stockbetrunken.v': {'stockbetrunken.v.01': 2},
#  'behindern.a': {'behindern.a.01': 2},
#  'Krawatte.n': {'Krawatte.n.01': 1},
#  'Fahrstuhl.n': {'Fahrstuhl.n.01': 2},
#  'köstlich.a': {'köstlich.a.01': 4},
#  'Kuchen.n': {'Kuchen.n.01': 2},
#  'schütteln.v': {'schütteln.v.01': 1},
#  'Baum.n': {'Baum.n.01': 1},
#  'BSN.n': {'female.n.02': 1},
#  'kaufen.v': {'kaufen.v.01': 13},
#  'RJR.n': {'female.n.02': 1},
#  'ergreifen.v': {'ergreifen.v.01': 4},
#  'Arm.n': {'Arm.n.01': 1},
#  'perfekt.a': {'perfekt.a.01': 2},
#  'Deutschland.n': {'female.n.02': 1},
#  'aufwachsen.a': {'aufwachsen.a.01': 1},
#  'Bronzemedaille.n': {'Bronzemedaille.n.01': 1},
#  'massieren.v': {'massieren.v.01': 1},
#  'bissig.a': {'bissig.a.01': 2},
#  'Hund.n': {'Hund.n.01': 4},
#  'verstoßen.v': {'verstoßen.v.01': 1},
#  'Gesetz.n': {'Gesetz.n.01': 1},
#  'Schutzhelm.n': {'Schutzhelm.n.01': 1},
#  'taufen.v': {'taufen.v.01': 1},
#  'ermutigen.v': {'ermutigen.v.01': 3},
#  'stattfinden.v': {'stattfinden.v.01': 1},
#  'Konferenz.n': {'Konferenz.n.01': 1},
#  'Geburtenkontrolle.n': {'Geburtenkontrolle.n.01': 1},
#  'öffnen.v': {'öffnen.v.01': 6},
#  'Argentinien.n': {'female.n.02': 2},
#  'Leloir.n': {'female.n.02': 1},
#  'El.n': {'female.n.02': 1},
#  'festnehmen.v': {'festnehmen.v.01': 2},
#  'bissen.v': {'bissen.v.01': 1},
#  'füllen.v': {'füllen.v.01': 2},
#  'bestehen.v': {'bestehen.v.01': 1},
#  'Fußballmannschaft.n': {'Fußballmannschaft.n.01': 1},
#  'erwerben.v': {'erwerben.v.01': 2},
#  'Fabrik.n': {'Fabrik.n.01': 1},
#  'Hosenträger.n': {'Hosenträger.n.01': 1},
#  'enteren.v': {'enteren.v.01': 2},
#  'Schiff.n': {'Schiff.n.01': 2},
#  'streicheln.v': {'streicheln.v.01': 1},
#  'manipulieren.v': {'manipulieren.v.01': 2},
#  'Mobiltelefon.n': {'Mobiltelefon.n.01': 1},
#  'entfernt.a': {'entfernt.a.01': 2},
#  'Postamt.n': {'Postamt.n.01': 1},
#  'erschießen.v': {'erschießen.v.01': 1},
#  'Steven.n': {'female.n.02': 1},
#  'Hawaii.n': {'female.n.02': 1},
#  'kosten.v': {'kosten.v.01': 11},
#  'Reise.n': {'Reise.n.01': 1},
#  'Infogear.n': {'female.n.02': 1},
#  'Cisco.n': {'female.n.02': 1},
#  'nicken.v': {'nicken_zu.v.01': 2},
#  'essen.v': {'essen.v.01': 7},
#  'Ann..n': {'female.n.02': 1},
#  'Mexiko.n': {'female.n.02': 3},
#  'Texas.n': {'female.n.02': 1},
#  'treffen.v': {'treffen.v.01': 2},
#  'Ball.n': {'Ball.n.01': 2},
#  'stehen.v': {'stehen.v.01': 2},
#  'Karren.n': {'Karren.n.01': 1},
#  'Jahr.n': {'Jahr.n.01': 2},
#  'achtzehn.n': {'achtzehn.n.01': 1},
#  '100.n': {'100.n.01': 1},
#  'schwärmen.v': {'schwärmen.v.01': 1},
#  'laufen.v': {'laufen.v.01': 2},
#  'Bahn.n': {'Bahn.n.01': 1},
#  'probieren.v': {'probieren.v.01': 2},
#  'Fabio.n': {'female.n.02': 1},
#  'Fisch.n': {'Fisch.n.01': 3},
#  'grinsen.v': {'grinsen.v.01': 1},
#  'fließen.v': {'fließen.v.01': 2},
#  'Fluß.n': {'Fluß.n.01': 2},
#  'erben.v': {'erben.v.01': 4},
#  'Tante.n': {'Tante.n.01': 1},
#  'greifen.v': {'greifen_an.v.01': 2},
#  'tippen.v': {'tippen.v.01': 2},
#  'krank.a': {'krank.a.01': 3},
#  'Moskau.n': {'female.n.02': 2},
#  'Vladislav.n': {'female.n.02': 2},
#  'ziemlich.r': {'ziemlich.r.01': 2},
#  'gelb.a': {'gelb.a.01': 2},
#  'fahren.v': {'fahren.v.01': 9},
#  'Abschleppwagen.n': {'Abschleppwagen.n.01': 1},
#  'Exknacki.n': {'Exknacki.n.01': 1},
#  'kratzen.v': {'kratzen.v.01': 1},
#  'bräunen.v': {'bräunen.v.01': 1},
#  'bekommen.v': {'bekommen.v.01': 2},
#  'schätzen.v': {'schätzen.v.01': 2},
#  'rennen.v': {'rennen.v.01': 4, 'rennen_weg.v.01': 2},
#  'entkemmen.v': {'entkemmen.v.01': 2},
#  'Stier.n': {'Stier.n.01': 1},
#  'feiern.v': {'feiern.v.01': 1},
#  'Spieler.n': {'Spieler.n.01': 1},
#  'Klavier.n': {'Klavier.n.01': 1},
#  'Chabrol.n': {'female.n.02': 1},
#  'Ebro.n': {'female.n.02': 1},
#  'nutzen.v': {'nutzen.v.01': 1},
#  'vorzüglich.a': {'vorzüglich.a.01': 2},
#  'Huhn.n': {'Huhn.n.01': 1},
#  'schließen.a': {'schließen.a.01': 4},
#  'Grenze.n': {'Grenze.n.01': 1},
#  'Paris.n': {'female.n.02': 2},
#  'Ford.n': {'female.n.02': 1},
#  'gründen.v': {'gründen.v.01': 1},
#  'Henry.n': {'female.n.02': 1},
#  'Kimono.n': {'Kimono.n.01': 1},
#  'Schwester.n': {'Schwester.n.01': 2},
#  'jung.a': {'jung.a.01': 4},
#  'dreißig.n': {'dreißig.n.01': 3},
#  'Sonnenbrille.n': {'Sonnenbrille.n.01': 2},
#  'weinen.v': {'weinen.v.01': 4},
#  'sehen.v': {'sehen.v.01': 4},
#  'hoch.a': {'hoch.a.01': 5},
#  'Turm.n': {'Turm.n.01': 2},
#  'Beleidigung.n': {'Beleidigung.n.01': 1},
#  'glibbern.v': {'glibbern.v.01': 2},
#  'Schleim.n': {'Schleim.n.01': 1},
#  'Minigolf.n': {'Minigolf.n.01': 1},
#  'fallen.a': {'fallen.a.01': 4},
#  'Apfel.n': {'Apfel.n.01': 1},
#  'bluten.v': {'bluten.v.01': 3},
#  'Varioobjektiv.n': {'Varioobjektiv.n.01': 1},
#  'zerreißen.v': {'zerreißen.v.01': 1},
#  'belieben.a': {'belieben.a.01': 3},
#  'verwüsten.v': {'verwüsten.v.01': 1},
#  'Europa.n': {'female.n.02': 1},
#  'beobachten.v': {'beobachten.v.01': 1},
#  'Historiker.n': {'Historiker.n.01': 1},
#  'Sachiko.n': {'female.n.02': 1},
#  'Muttersprache.n': {'Muttersprache.n.01': 7},
#  'bezahlen.v': {'bezahlen.v.01': 3},
#  'Visum.n': {'Visum.n.01': 1},
#  'platschen.v': {'platschen.v.01': 2},
#  'Wange.n': {'Wange.n.01': 1},
#  'Lötlampe.n': {'Lötlampe.n.01': 2},
#  'Musiker.n': {'Musiker.n.01': 1},
#  'Beatles.n': {'Beatles.n.01': 1},
#  'Trottel.n': {'Trottel.n.01': 1},
#  'lauten.v': {'lauten.v.01': 1},
#  'buchen.v': {'buchen.v.01': 3},
#  'Zimmer.n': {'Zimmer.n.01': 2},
#  'langweilen.v': {'langweilen.v.01': 2},
#  'Großvater.n': {'Großvater.n.01': 1},
#  'nehmen.v': {'nehmen_an.v.01': 1,
#   'nehmen_auf.v.01': 2,
#   'nehmen_auseinander.v.01': 1},
#  'Geschenk.n': {'Geschenk.n.01': 1},
#  'blau.a': {'blau.a.01': 1},
#  'erbrechen.v': {'erbrechen.v.01': 1},
#  'fliegen.v': {'fliegen.v.01': 3},
#  'River.n': {'female.n.02': 1},
#  'Allan.n': {'female.n.02': 1},
#  'entdecken.v': {'entdecken.v.01': 2},
#  'Strand.n': {'Strand.n.01': 1},
#  'gesellig.a': {'gesellig.a.01': 1},
#  'stöhnen.v': {'stöhnen.v.01': 1},
#  'spinnen.v': {'spinnen.v.01': 3},
#  'machen.v': {'machen.v.01': 4},
#  'Salto.n': {'Salto.n.01': 1},
#  'Nazi.n': {'Nazi.n.01': 1},
#  'meißeln.a': {'meißeln.a.01': 1},
#  'unvollständig.a': {'unvollständig.a.01': 2},
#  'Teeservice.n': {'Teeservice.n.01': 1},
#  'heulen.v': {'heulen.v.01': 2},
#  'Wind.n': {'Wind.n.01': 3},
#  'atmen.v': {'atmen.v.01': 2},
#  'stürzen.v': {'stürzen_ein.v.01': 1},
#  'Zigarette.n': {'Zigarette.n.01': 1},
#  'Browne.n': {'female.n.02': 1},
#  'Akkordeon.n': {'Akkordeon.n.01': 1},
#  'Verlobte.n': {'Verlobte.n.01': 1},
#  'brauchen.v': {'brauchen.v.01': 1},
#  'Kugelschreiber.n': {'Kugelschreiber.n.01': 1},
#  'Dieb.n': {'Dieb.n.01': 1},
#  'münden.v': {'münden.v.01': 2},
#  'Liegestütze.n': {'Liegestütze.n.01': 1},
#  'beleidigt.v': {'beleidigt.v.01': 3},
#  'öffentlich.r': {'öffentlich.r.01': 1},
#  'kreisen.v': {'kreisen.v.01': 2},
#  'Hubschrauber.n': {'Hubschrauber.n.01': 1},
#  'Homerun.n': {'Homerun.n.01': 1},
#  'kichern.v': {'kichern.v.01': 1},
#  'fauchen.v': {'fauchen_an.v.01': 1},
#  'kochen.v': {'kochen.v.01': 3},
#  'japanisch.a': {'japanisch.a.01': 1},
#  'Tablette.n': {'Tablette.n.01': 1},
#  'Pfirsichbaum.n': {'Pfirsichbaum.n.01': 1},
#  'stürmen.v': {'stürmen.v.01': 1},
#  'Einbrecher.n': {'Einbrecher.n.01': 1},
#  'kollern.v': {'kollern.v.01': 1},
#  'erfinden.v': {'erfinden.v.01': 1},
#  'verbringen.v': {'verbringen.v.01': 1},
#  'Tom?.n': {'female.n.02': 2},
#  'Cabrio.n': {'Cabrio.n.01': 1},
#  'liegen.v': {'liegen.v.01': 5},
#  'Tisch.n': {'Tisch.n.01': 2},
#  'gestehen.v': {'gestehen_ein.v.01': 1},
#  'Fehler.n': {'Fehler.n.01': 1},
#  'zeichnen.v': {'zeichnen.v.01': 2},
#  'töten.v': {'töten.v.01': 2},
#  'Hirsch.n': {'female.n.02': 1},
#  'lindern.v': {'lindern.v.01': 1},
#  'umbringen.v': {'umbringen.v.01': 3},
#  'Bill.n': {'female.n.02': 2},
#  'kenteren.v': {'kenteren.v.01': 1},
#  'roh.a': {'roh.a.01': 2},
#  'Fleisch.n': {'Fleisch.n.01': 2},
#  'wichtig.a': {'wichtig.a.01': 2},
#  'Meinung.n': {'Meinung.n.01': 1},
#  'singen.v': {'singen.v.01': 4},
#  'Lied.n': {'Lied.n.01': 1},
#  'enorm.a': {'enorm.a.01': 2},
#  'flirten.v': {'flirten.v.01': 1},
#  'kein.n': {'kein.n.01': 1},
#  'Problem.n': {'Problem.n.01': 1},
#  'neu.a': {'neu.a.01': 2},
#  'Rock.n': {'Rock.n.01': 1},
#  'sprechen.v': {'sprechen.v.01': 11},
#  'eifersüchtig.a': {'eifersüchtig.a.01': 3},
#  'schrei.v': {'schrei.v.01': 2},
#  'Gabriel.n': {'female.n.02': 2},
#  'Autor.n': {'Autor.n.01': 1},
#  'Yokohama.n': {'female.n.02': 1},
#  'anlaufen.v': {'anlaufen.v.01': 2},
#  'wiegeln.v': {'wiegeln_auf.v.01': 2},
#  'Politiker.n': {'Politiker.n.01': 1},
#  'Peking.n': {'female.n.02': 1},
#  'Vater.n': {'Vater.n.01': 1},
#  'sitzen.v': {'sitzen.v.01': 1},
#  'Fußballer.n': {'Fußballer.n.01': 1},
#  'erstechen.v': {'erstechen.v.01': 1},
#  'entlassen.v': {'entlassen.v.01': 4},
#  'Zimmermädchen.n': {'Zimmermädchen.n.01': 1},
#  'heiß.a': {'heiß.a.01': 4},
#  'Ofen.n': {'Ofen.n.01': 1},
#  'stecken.v': {'stecken.v.01': 2},
#  'Zwickmühle.n': {'Zwickmühle.n.01': 1},
#  'warm.a': {'warm.a.01': 2},
#  'heben.v': {'heben_auf.v.01': 4},
#  'Stein.n': {'Stein.n.01': 1},
#  'Stephen.n': {'female.n.02': 2},
#  'Physiker.n': {'Physiker.n.01': 1},
#  'dick.n': {'dick.n.02': 4},
#  'Sohn.n': {'Sohn.n.01': 2},
#  'grunzen.v': {'grunzen.v.01': 1},
#  'heuern.v': {'heuern_an.v.01': 1},
#  'begrapschen.v': {'begrapschen.v.01': 1},
#  'besitzen.v': {'besitzen.v.01': 1},
#  'Automobile.n': {'Automobile.n.01': 1},
#  'schern.v': {'schern.v.01': 2},
#  'besetzen.a': {'besetzen.a.01': 2},
#  'Nummer.n': {'Nummer.n.01': 1},
#  'Freund.n': {'Freund.n.01': 1},
#  'legen.v': {'legen_an.v.01': 1, 'legen.v.01': 3},
#  'Schürz.n': {'Schürz.n.01': 1},
#  'Mont.n': {'female.n.02': 1},
#  'bezwingen.v': {'bezwingen.v.01': 4},
#  'bestellen.v': {'bestellen.v.01': 4},
#  'Pizza.n': {'Pizza.n.01': 1},
#  'Rechnung.n': {'Rechnung.n.01': 1},
#  'sinken.v': {'sinken.v.01': 1},
#  'allergisch.a': {'allergisch.a.01': 2},
#  'Rückfahrkarte.n': {'Rückfahrkarte.n.01': 1},
#  'lächeln.v': {'lächeln_an.v.01': 2},
#  'lachen.v': {'lachen.v.01': 5, 'lachen_aus.v.01': 2},
#  'Wagner.n': {'female.n.02': 1},
#  'Immobilienmaklerin.n': {'Immobilienmaklerin.n.01': 1},
#  'küssen.v': {'küssen.v.01': 2},
#  'rauchen.v': {'rauchen.v.01': 2},
#  'gehen.v': {'gehen.v.01': 4},
#  'wer.n': {'wer.n.01': 1},
#  'groß.a': {'groß.a.01': 6},
#  'Mikroskop.n': {'Mikroskop.n.01': 1},
#  'Metin.n': {'female.n.02': 1},
#  'Ibrahim.n': {'female.n.02': 1},
#  'ausbrechen.a': {'ausbrechen.a.01': 1},
#  'Hokkaidō.n': {'female.n.02': 1},
#  'breit.a': {'breit.a.01': 4},
#  'Straße.n': {'Straße.n.01': 1},
#  'reparieren.v': {'reparieren.v.01': 1},
#  'alle.n': {'alle.n.01': 2},
#  'Lehrerin.n': {'Lehrerin.n.01': 1},
#  'Friedrichs.n': {'female.n.02': 1},
#  'gekneffen.v': {'gekneffen.v.01': 2},
#  'Tarō.n': {'female.n.02': 1},
#  'hängen.v': {'hängen.v.01': 4},
#  'Leine.n': {'Leine.n.01': 1},
#  'weggerannt.a': {'weggerannt.a.01': 1},
#  'verlieben.a': {'verlieben.a.01': 1},
#  'Arsch.n': {'Arsch.n.01': 2},
#  'zeigen.v': {'zeigen.v.01': 2},
#  'Bild.n': {'Bild.n.01': 1},
#  'Heinrich.n': {'female.n.02': 2},
#  'Zauberer.n': {'Zauberer.n.01': 1},
#  'wollen.v': {'wollen.v.01': 1},
#  'Hundewelpe.n': {'Hundewelpe.n.01': 1},
#  'Golf.n': {'Golf.n.01': 1},
#  'tief.a': {'tief.a.01': 6},
#  'schwächlich.a': {'schwächlich.a.01': 1},
#  'japanisch.n': {'japanisch.n.01': 3},
#  'Englisch.n': {'Englisch.n.01': 1},
#  'Französisch.n': {'Französisch.n.01': 1},
#  'Katze.n': {'Katze.n.01': 3},
#  'Flüchtling.n': {'Flüchtling.n.01': 1},
#  'Syrer.n': {'Syrer.n.01': 1},
#  'suchen.v': {'suchen.v.01': 2},
#  'Wurm.n': {'Wurm.n.01': 1},
#  'schulden.v': {'schulden.v.01': 1},
#  'wissen.v': {'wissen.v.01': 1},
#  'kauen.v': {'kauen_herum.v.01': 1},
#  'Edwin.n': {'female.n.02': 1},
#  'ca..r': {'ca..r.01': 1},
#  'bekleiden.a': {'bekleiden.a.01': 2},
#  'Louis.n': {'female.n.02': 1},
#  'Scott.n': {'female.n.02': 1},
#  'wert.a': {'wert.a.01': 1},
#  'verachten.v': {'verachten.v.01': 1},
#  'Radium.n': {'female.n.02': 1},
#  'drücken.v': {'drücken.v.01': 1},
#  'Knopf.n': {'Knopf.n.01': 1},
#  'egal.a': {'egal.a.01': 2},
#  'vollkommen.r': {'vollkommen.r.01': 1},
#  'zitieren.v': {'zitieren.v.01': 2},
#  'Keats.n': {'female.n.02': 1},
#  'oben.r': {'oben.r.01': 2},
#  'Toilette.n': {'Toilette.n.01': 1},
#  'Madonnas.n': {'female.n.02': 1},
#  'Eurofin.n': {'female.n.02': 1},
#  'ertränken.v': {'ertränken.v.01': 2},
#  'Bach.n': {'Bach.n.01': 1},
#  'guillotinieren.v': {'guillotinieren.v.01': 1},
#  'Marie.n': {'female.n.02': 1},
#  'Depp.n': {'Depp.n.01': 1},
#  'Melbourne.n': {'female.n.02': 1},
#  'Laurie.n': {'female.n.02': 1},
#  'verfolgen.v': {'verfolgen.v.01': 2},
#  'Polizist.n': {'Polizist.n.01': 1},
#  'Schloß.n': {'Schloß.n.01': 1},
#  'Krieg.n': {'Krieg.n.01': 1},
#  'Jack.n': {'female.n.02': 1},
#  'Jill.n': {'female.n.02': 1},
#  'verständnisvoll.a': {'verständnisvoll.a.01': 3},
#  'Eis.n': {'Eis.n.01': 1},
#  'vollkommen.a': {'vollkommen.a.01': 2},
#  'schalten.v': {'schalten.v.01': 2},
#  'Kreditkarte.n': {'Kreditkarte.n.01': 1},
#  'beschnüffeln.v': {'beschnüffeln.v.01': 2},
#  'protestieren.v': {'protestieren.v.01': 1},
#  'Tur.n': {'Tur.n.01': 1},
#  'Bier.n': {'Bier.n.01': 1},
#  'Pappteller.n': {'Pappteller.n.01': 1},
#  'hellrot.a': {'hellrot.a.01': 1},
#  'Tennisspieler.n': {'Tennisspieler.n.01': 1},
#  'miauen.v': {'miauen.v.01': 1},
#  'Irak.n': {'female.n.02': 1},
#  'schicken.v': {'schicken.v.01': 1},
#  'leer.a': {'leer.a.01': 2},
#  'Disko.n': {'Disko.n.01': 1},
#  'zählen.v': {'zählen.v.01': 1},
#  'Handtücher.n': {'Handtücher.n.01': 1},
#  'Bruder.n': {'Bruder.n.01': 1},
#  'Zentimeter.n': {'Zentimeter.n.01': 1},
#  '180.n': {'180.n.01': 1},
#  'Soldat.n': {'Soldat.n.01': 1},
#  'begehen.v': {'begehen.v.01': 1},
#  'Verbrechen.n': {'Verbrechen.n.01': 1},
#  'mißfallen.v': {'mißfallen.v.01': 1},
#  'niederbrennen.v': {'niederbrennen.v.01': 1},
#  'tun.v': {'tun_weh.v.01': 1},
#  'meauen.v': {'meauen.v.01': 1},
#  'verschütten.v': {'verschütten.v.01': 1},
#  'Milch.n': {'Milch.n.01': 1},
#  'schicken.a': {'schicken.a.01': 1},
#  'brauen.v': {'brauen.v.01': 2},
#  'vergeben.v': {'vergeben.v.01': 2},
#  'nachlassen.v': {'nachlassen.v.01': 2},
#  'lassen.v': {'lassen.v.01': 1},
#  'schäkern.v': {'schäkern.v.01': 2},
#  'lernen.v': {'lernen.v.01': 3},
#  'Chinesisch.n': {'Chinesisch.n.01': 2},
#  'Wolke.n': {'Wolke.n.01': 1},
#  'fassen.v': {'fassen.v.01': 1},
#  'entfernen.v': {'entfernen.v.01': 1},
#  'Splitter.n': {'Splitter.n.01': 1},
#  'besiegen.v': {'besiegen.v.01': 4},
#  'Damespiel.n': {'Damespiel.n.01': 1},
#  'Kinderspiel.n': {'Kinderspiel.n.01': 2},
#  'ticken.v': {'ticken.v.01': 2},
#  'Uhr.n': {'Uhr.n.01': 1},
#  'klein.a': {'klein.a.01': 2},
#  'Syrien.n': {'female.n.02': 1},
#  'Damaskus.n': {'female.n.02': 1},
#  'amüsieren.v': {'amüsieren.v.01': 1},
#  'hungrig.a': {'hungrig.a.01': 1},
#  'Zahnarzt.n': {'Zahnarzt.n.01': 1},
#  'Silbermedaille.n': {'Silbermedaille.n.01': 1},
#  'müde.a': {'müde.a.01': 1},
#  'Johannes.n': {'female.n.02': 2},
#  'Fange.n': {'Fange.n.01': 1},
#  'schnitzen.v': {'schnitzen.v.01': 2},
#  'Junge.n': {'Junge.n.01': 2},
#  'Kasachstan.n': {'female.n.02': 1},
#  'Handschrift.n': {'Handschrift.n.01': 2},
#  'wegtransportieren.v': {'wegtransportieren.v.01': 2},
#  'Verletzte.n': {'Verletzte.n.01': 1},
#  'Pfeilewerfen.n': {'Pfeilewerfen.n.01': 1},
#  'Zigarre.n': {'Zigarre.n.01': 2},
#  'Mark.n': {'female.n.02': 1},
#  'Mona.n': {'female.n.02': 1},
#  'Leonardo.n': {'female.n.02': 1},
#  'malen.v': {'malen.v.01': 1},
#  'springen.v': {'springen.v.01': 1},
#  'gehören.v': {'gehören.v.01': 1},
#  'besoffen.a': {'besoffen.a.01': 3},
#  'voll.r': {'voll.r.01': 1},
#  'normal.a': {'normal.a.01': 2},
#  'kaltstellen.v': {'kaltstellen.v.01': 1},
#  'lecken.v': {'lecken.v.01': 1},
#  'führen.v': {'führen_an.v.01': 2},
#  'Liste.n': {'Liste.n.01': 1},
#  'berechnen.v': {'berechnen.v.01': 2},
#  'Feier.n': {'Feier.n.01': 1},
#  'befreit.v': {'befreit.v.01': 1},
#  'waren.v': {'waren.v.01': 1},
#  'Telefonanruf.n': {'Telefonanruf.n.01': 1},
#  'vermuten.v': {'vermuten.v.01': 2},
#  'pfeffen.v': {'pfeffen.v.01': 3},
#  'Liedchen.n': {'Liedchen.n.01': 1},
#  'Becher.n': {'Becher.n.01': 2},
#  'Irving.n': {'female.n.02': 1},
#  'zücken.v': {'zücken.v.01': 1},
#  'Stricknadeln.n': {'Stricknadeln.n.01': 1},
#  'Liisas.n': {'female.n.02': 1},
#  'rülpen.v': {'rülpen.v.01': 2},
#  'aufheben.a': {'aufheben.a.01': 1},
#  'Truckee.n': {'female.n.02': 1},
#  'Dean.n': {'female.n.02': 1},
#  'ausgerutscht.a': {'ausgerutscht.a.01': 1},
#  'erzählen.v': {'erzählen.v.01': 1},
#  'zwanzig.n': {'zwanzig.n.01': 1},
#  'St..n': {'female.n.02': 1},
#  'verbannen.v': {'verbannen.v.01': 1},
#  'White.n': {'female.n.02': 2},
#  'Auto.n': {'Auto.n.01': 2},
#  'Eimer.n': {'Eimer.n.01': 1},
#  'hell.a': {'hell.a.01': 1},
#  'allzu.r': {'allzu.r.01': 1},
#  'klagen.v': {'klagen_an.v.01': 2},
#  'Mord.n': {'Mord.n.01': 1},
#  'schreiben.v': {'schreiben.v.01': 4},
#  'Lkw.n': {'Lkw.n.01': 1},
#  'Aff.n': {'Aff.n.01': 1},
#  'schlecht.a': {'schlecht.a.01': 2},
#  'einige.n': {'einige.n.01': 1},
#  'hebräisch.a': {'hebräisch.a.01': 1},
#  'Meter.n': {'Meter.n.01': 1},
#  'verbieten.a': {'verbieten.a.01': 2},
#  'Spuck|Spucken.n': {'Spuck|Spucken.n.01': 1},
#  'tanzen.v': {'tanzen.v.01': 2},
#  'fraßen.v': {'fraßen.v.01': 1},
#  'brechen.v': {'brechen_aus.v.01': 3, 'brechen_ein.v.01': 1},
#  'Revolution.n': {'Revolution.n.01': 1},
#  'bekifft.a': {'bekifft.a.01': 1},
#  'vergiften.v': {'vergiften.v.01': 2},
#  'arabisch.a': {'arabisch.a.01': 1},
#  'süchtig.a': {'süchtig.a.01': 1},
#  'kennen.v': {'kennen.v.01': 1},
#  'spenden.v': {'spenden.v.01': 1},
#  'Geld.n': {'Geld.n.01': 1},
#  'Gracia.n': {'female.n.02': 1},
#  'Hughes.n': {'female.n.02': 1},
#  'verheiraten.a': {'verheiraten.a.01': 1},
#  'servieren.v': {'servieren.v.01': 2},
#  'Dienstmädchen.n': {'Dienstmädchen.n.01': 1},
#  'Suppe.n': {'Suppe.n.01': 1},
#  'lügen.v': {'lügen.v.01': 2},
#  'Tee.n': {'Tee.n.01': 1},
#  'Euro.n': {'female.n.02': 1},
#  'Raymond.n': {'female.n.02': 2},
#  'aufnehmen.v': {'aufnehmen.v.01': 1},
#  'Volksabstimmung.n': {'Volksabstimmung.n.01': 1},
#  'Jesus.n': {'female.n.02': 1},
#  'Bauchmuskel.n': {'Bauchmuskel.n.01': 1},
#  'Stahl.n': {'Stahl.n.01': 1},
#  'Einstein.n': {'female.n.02': 1},
#  'wehen.v': {'wehen.v.01': 2},
#  'Max.n': {'female.n.02': 1},
#  'Sandra.n': {'female.n.02': 1},
#  'graben.v': {'graben.v.01': 2},
#  'unbekümmert.a': {'unbekümmert.a.01': 3},
#  'fünf.n': {'fünf.n.01': 1},
#  'Chauffeur.n': {'Chauffeur.n.01': 1},
#  'häuten.v': {'häuten.v.01': 2},
#  'Vogel.n': {'Vogel.n.01': 1},
#  'sie.n': {'female.n.02': 1},
#  'Garten.n': {'Garten.n.01': 1},
#  'ruinieren.v': {'ruinieren.v.01': 1},
#  'nahen.v': {'nahen.v.01': 2},
#  'verstecken.v': {'verstecken.v.01': 1},
#  'Kassettenrekorder.n': {'Kassettenrekorder.n.01': 1},
#  'cool.a': {'cool.a.02': 3},
#  'verdammen.r': {'verdammen.r.01': 1},
#  'berühren.v': {'berühren.v.01': 2},
#  'weben.v': {'weben.v.01': 1},
#  'begeistern.a': {'begeistern.a.01': 1},
#  'stoßen.v': {'stoßen.v.01': 1},
#  'Kater.n': {'Kater.n.01': 1},
#  'verursachen.v': {'verursachen.v.01': 1},
#  'Unfall.n': {'Unfall.n.01': 1},
#  'Smoking.n': {'Smoking.n.01': 1},
#  'China.n': {'female.n.02': 1},
#  'Fernbedienung.n': {'Fernbedienung.n.01': 1},
#  'verletzen.a': {'verletzen.a.01': 2},
#  'übel.r': {'übel.r.01': 1},
#  'verbreitern.v': {'verbreitern.v.01': 1},
#  'zerstört.v': {'zerstört.v.01': 1},
#  'Gebäude.n': {'Gebäude.n.01': 1},
#  'siebzehn.n': {'siebzehn.n.01': 1},
#  'klug.a': {'klug.a.01': 1},
#  'Sprung.n': {'Sprung.n.01': 2},
#  'geduldig.a': {'geduldig.a.01': 3},
#  'regnen.v': {'regnen.v.01': 1},
#  'Regen.n': {'Regen.n.01': 1},
#  'Ruth.n': {'female.n.02': 1},
#  'dagelassen.v': {'dagelassen.v.01': 2},
#  'Neugier.n': {'female.n.02': 1},
#  'Holzpuppe.n': {'Holzpuppe.n.01': 1},
#  'berühmt.a': {'berühmt.a.01': 2},
#  'Baseballspieler.n': {'Baseballspieler.n.01': 1},
#  'Teich.n': {'Teich.n.01': 1},
#  'Pullover.n': {'Pullover.n.01': 1},
#  'frieren.a': {'frieren.a.01': 2},
#  'Fußball.n': {'Fußball.n.01': 1},
#  'einsam.a': {'einsam.a.01': 2},
#  'Mädchen.n': {'Mädchen.n.01': 1},
#  'Bahnhof.n': {'Bahnhof.n.01': 1},
#  'Pesos.n': {'Pesos.n.01': 1},
#  'hundert.n': {'hundert.n.01': 1},
#  'lustig.a': {'lustig.a.01': 3},
#  'es.n': {'person.n.01': 1},
#  'irgendwie.r': {'irgendwie.r.01': 1},
#  'ausgesprochen.r': {'ausgesprochen.r.01': 1},
#  'Charlie.n': {'female.n.02': 2},
#  'erwarten.v': {'erwarten.v.01': 3},
#  'Schaden.n': {'Schaden.n.01': 1},
#  'halten.v': {'halten.v.01': 1},
#  'Susanna.n': {'female.n.02': 1},
#  'prallen.v': {'prallen_ab.v.01': 2},
#  'Helm.n': {'Helm.n.01': 1},
#  'jagen.v': {'jagen.v.01': 2},
#  'blockieren.a': {'blockieren.a.01': 1},
#  'brennen.v': {'brennen_ab.v.01': 1},
#  'strahlen.v': {'strahlen.v.01': 2},
#  'Sonne.n': {'Sonne.n.01': 1},
#  'knurren.v': {'knurren.v.01': 2},
#  'Mage.n': {'Mage.n.01': 1},
#  'Exfrau.n': {'Exfrau.n.01': 1},
#  'blasen.v': {'blasen.v.01': 2},
#  'CD.n': {'CD.n.01': 1},
#  'hereinlegen.v': {'hereinlegen.v.01': 2},
#  'Taifun.n': {'Taifun.n.01': 1}}
