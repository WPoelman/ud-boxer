# %%
import pandas as pd

# PATH = 'data/results/full_gold_run/en_gold_all.csv'
# PATH = '../data/results/rewrite/en/eval/final_stanza.csv'
# PATH = '../data/results/rewrite/en/eval/final_stanza.csv'
PATH = '../data/results/rewrite/de/test/final_trankit.csv'

df = pd.read_csv(PATH)

# %%
# Best scoring sentences
df[df.sbn_str.str.contains('NEGATION')].sort_values('f1', ascending=False).head(20).sort_values(by="raw_sent", key=lambda x: x.str.len(), ascending=False)
# Out:
#            pmb_id source                               raw_sent  \
# 310  de/p72/d2529   GREW  Du bist nicht weniger hübsch wie sie.
# 365  de/p02/d2269   GREW    Ihr Hund ist nicht besonders flink.
# 178  de/p32/d1472   GREW     Tom ist überhaupt nicht glücklich.
# 534  de/p82/d2292   GREW       Jane ist nicht so groß wie Mary.
# 30   de/p12/d1544   GREW        Der Drucker funktioniert nicht.
# 65   de/p62/d1986   GREW         Ich habe auch nicht angerufen.
# 494  de/p21/d0875   GREW          In diesem Haus wohnt niemand.
# 214  de/p91/d2487   GREW          Die Ampel funktioniert nicht.
# 22   de/p12/d3065   GREW          Er ist nicht reicher als ich.
# 503  de/p21/d1918   GREW           Die Waffe ist nicht geladen.
# 161  de/p32/d2221   GREW            Wir sind nicht verheiratet.
# 332  de/p81/d1878   GREW            Ich traue Politikern nicht.
# 77   de/p62/d3416   GREW            Ich habe nie Golf gespielt.
# 199  de/p91/d1766   GREW            Wir sind nicht verheiratet.
# ...

# %%
PATH = '../data/results/seq2seq/eval/results_strict_indices_gold_silver.csv'
df = pd.read_csv(PATH)
df.sort_values('f1', ascending=True).head(100)
# Out:
#            pmb_id   source                                           raw_sent  \
# 83   en/p60/d2345  SEQ2SEQ       I thought that guy had a gun, so I shot him.
# 330  en/p50/d2289  SEQ2SEQ                                       Holy smokes.
# 524  en/p70/d0764  SEQ2SEQ  Victor Emmanuel III was king of Italy from 190...
# 766  en/p80/d3313  SEQ2SEQ                                     I'm all alone.
# 790  en/p80/d2803  SEQ2SEQ           Is there a washing machine in the house?
# ..            ...      ...                                                ...
# 564  en/p90/d0718  SEQ2SEQ           Wal-Mart has violated state regulations.
# 542  en/p90/d2522  SEQ2SEQ                  Mary bought a fake Gucci handbag.
# 403  en/p70/d1509  SEQ2SEQ                     The room had a nice cozy feel.
# 151  en/p60/d1742  SEQ2SEQ                      I was aching for a cigarette.
# 349  en/p50/d1585  SEQ2SEQ            The drunken man couldn't walk straight.
#
# ...

# %%
df[df.f1_lenient > .8]
# Out:
#            pmb_id source                                   raw_sent  \
# 3    en/p60/d3280   GREW  She wrapped her sandwich in plastic wrap.
# 4    en/p60/d2142   GREW                          Tom was defeated.
# 6    en/p60/d2753   GREW                   He spoke to the teacher.
# 7    en/p60/d2324   GREW                            Tom has a ring.
# 11   en/p60/d0911   GREW                He shaved his mustache off.
# ..            ...    ...                                        ...
# 815  en/p80/d2886   GREW                 Tom pointed a gun at Mary.
# 821  en/p80/d1880   GREW                        Tom is a bit crazy.
# 823  en/p80/d0826   GREW                        We ran out of food.
# 824  en/p80/d2755   GREW                   I wanted to go to China.
# 825  en/p80/d2267   GREW                    He is knitting a scarf.
#
#                                                sbn_str error  precision  \
# 3    time.n.08         TPR now\nfemale.n.02\nwrap.v...   NaN   0.846154
# ...

# %%
# Worst scoring sentences
# df.sort_values('f1_lenient', ascending=True).head(50).to_csv('test.csv', index=False)
df.sort_values('f1', ascending=True).head(50)
# Out:
#            pmb_id source                                           raw_sent  \
# 82   en/p60/d2345   GREW       I thought that guy had a gun, so I shot him.
# 515  en/p70/d0764   GREW  Victor Emmanuel III was king of Italy from 190...
# 756  en/p80/d1477   GREW                        Tom is Mary's ex-boyfriend.
# 603  en/p90/d2490   GREW                                You can't run away.
# 250  en/p50/d2233   GREW                    Charles I had his head cut off.
# 599  en/p90/d2927   GREW                     I have to tighten these bolts.
# 50   en/p60/d0913   GREW                                A cat has two ears.
# 650  en/p90/d2854   GREW         She was born at six a.m. on July 17, 1990.
# 654  en/p90/d0841   GREW                                    He cannot swim.
# 786  en/p80/d2961   GREW                         I have to print 100 pages.
# 488  en/p70/d2331   GREW           You should be ashamed of your stupidity.
# ...

# %%
# Get long sentences that score high
df.sort_values("raw_sent", key=lambda x: x.str.len(), ascending=False) \
    .head(200) \
    .sort_values('f1_lenient', ascending=False) \
    [['pmb_id', 'raw_sent', 'f1', 'f1_lenient']]
# Out:
#            pmb_id                                           raw_sent  \
# 340  en/p50/d1422  The trip was canceled because of a terrible st...
# 93   en/p60/d2409  The curtain fell amid the wild applause of the...
# 313  en/p50/d2041             Tom counted the flowers in the garden.
# 770  en/p80/d1895       The note is jotted directly on the envelope.
# 661  en/p90/d1634        The girl is buying milk at the supermarket.
# ..            ...                                                ...
# 515  en/p70/d0764  Victor Emmanuel III was king of Italy from 190...
# 82   en/p60/d2345       I thought that guy had a gun, so I shot him.
# 555  en/p90/d2729  The little girl, deeply moved by the old man's...
# 28   en/p60/d2141            There are a lot of tattoos on her body.
# 187  en/p50/d2408             All of my friends like computer games.
#
#            f1  f1_lenient
# 340  0.939394    0.964286
# 93   0.897436    0.939394
# 313  0.942857    0.933333
# 770  0.909091    0.928571
# ...

# %%
df[df.error.notnull()]
# Out:
#            pmb_id source                                           raw_sent  \
# 28   en/p60/d2141   GREW            There are a lot of tattoos on her body.
# 91   en/p60/d1786   GREW                        All of my friends like Tom.
# 187  en/p50/d2408   GREW             All of my friends like computer games.
# 555  en/p90/d2729   GREW  The little girl, deeply moved by the old man's...
#
#     sbn_str                                              error  precision  \
# 28      NaN  Exporting a cyclic SBN graph to Penman is not ...        NaN
# 91      NaN  All nodes need the 'token' features. Node data...        NaN
# 187     NaN  All nodes need the 'token' features. Node data...        NaN
# 555     NaN  Exporting a cyclic SBN graph to Penman is not ...        NaN
#
#      recall  f1  precision_lenient  recall_lenient  f1_lenient
# 28      NaN NaN                NaN             NaN         NaN
# 91      NaN NaN                NaN             NaN         NaN
# ...
